# %% [markdown]
# ### Tuples

# %% [markdown]
# Tuples are ordered collections of items that are immutable. they are simialr to lists, but their immutability makes them diffrent.

# %%
## creating a tuple
empty_tuple=()
print(f"{empty_tuple},{type(empty_tuple)}")
# Out:
# (),<class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
## add elements IN TUPLES
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuples=(1,"hello",3.14,True)
mixed_tuples
# Out:
# (1, 'hello', 3.14, True)

# %%
## Accessing tuple elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[0]
# Out:
# 1

# %%
## Tuple Operations

concatination = numbers + mixed_tuples
concatination
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'hello', 3.14, True)

# %%
mixed_tuples * 3
# Out:
# (1, 'hello', 3.14, True, 1, 'hello', 3.14, True, 1, 'hello', 3.14, True)

# %%
## Imuutable nature of tuples
## tuples are immutable, meaning their elements cannot be changes once assigned.

lst=[1,2,3,4,5]
print(lst)

lst[1]="Ram"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Ram', 3, 4, 5]

# %%
numbers=(1,2,3,4,5)
numbers[1]=5

## this is the immutable property
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1710931156.py in <cell line: 0>()
#       1 numbers=(1,2,3,4,5)
# ----> 2 numbers[1]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
## tuple Methods

numbers
# Out:
# (1, 2, 3, 4, 5)

# %%
print(numbers.count(1))
print(numbers.index(3)) ## which index the number is present (first index only)
# Out:
# 1
# 2

# %%
## Packing and unpacking Tuple

pack_tuple = 1,"hello",3.14
print(pack_tuple)
# Out:
# (1, 'hello', 3.14)

# %%
## unpack
a,b,c=pack_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# hello
# 3.14

# %%
## unpacking with *

numbers=(1,2,3,4,5,6)
first,*mid,last=numbers

print(first)
print(mid)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## Nested tuple
## nested list

lst=[[1,2,3,4],[6,7,8,9],[1,"hello",3.14,"c"]]
print(lst[0][2])
print(lst[0][0:3])
# Out:
# 3
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"hello",3.14,"c")]
print(lst[2][0:3])
# Out:
# (1, 'hello', 3.14)

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))
nested_tuple[1][2]
# Out:
# 'c'

# %%
## iterating

for sub_tuple in nested_tuple:
  for item in sub_tuple:
    print(item,end=" ")
  print()
# Out:
# 1 2 3
# a b c
# True False

# %% [markdown]
# ### Conclusion
#
# Tuples are versatile and useful in many real-world scenarios where an immutable and orders collection of items is req. They are commonly used in data structures, function arguments and return values, and as dictionary keys.
